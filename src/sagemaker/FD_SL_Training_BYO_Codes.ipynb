# %% [markdown]
# # Fraud Detection Solution Training Notebook
#
# This notebook shows the 1st time training process of a fraud detection model using graph neural networks in the Solution.
#
# This notebook assumes the transaction data has been dumped out from the Neptune DB, and copied to S3 bukets. So the input data has already in S3.
#
# Then we create a launch of training job using the SageMaker framework estimator to train a graph neural network model with DGL.

# %%
# !bash setup.sh

import sagemaker
from sagemaker_graph_fraud_detection import config, container_build

role = config.role
sess = sagemaker.Session()
# Out:
# Obtaining file:///home/ec2-user/SageMaker/sagemaker_graph_fraud_detection
# Installing collected packages: sagemaker-graph-fraud-detection
#   Attempting uninstall: sagemaker-graph-fraud-detection
#     Found existing installation: sagemaker-graph-fraud-detection 1.0
#     Uninstalling sagemaker-graph-fraud-detection-1.0:
#       Successfully uninstalled sagemaker-graph-fraud-detection-1.0
#   Running setup.py develop for sagemaker-graph-fraud-detection
# Successfully installed sagemaker-graph-fraud-detection

# %% [markdown]
# ## Define Data Location

# %% [markdown]
# ### Loading Pre-processed data from S3
#
# The dataset used in this Solution is the [IEEE-CIS Fraud Detection dataset](https://www.kaggle.com/c/ieee-fraud-detection/data?select=train_transaction.csv) which is a typical example of financial transactions dataset that many companies have. The dataset consists of two tables:
#
# * **Transactions**: Records transactions and metadata about transactions between two users. Examples of columns include the product code for the transaction and features on the card used for the transaction.
# * **Identity**: Contains information about the identity users performing transactions. Examples of columns here include the device type and device ids used.
#
# This notebook assumes that the two data tables had been pre-processed, mimicing the 1st time data preparation.
#
# **Current version uses the pre-processed data in nearly raw format, include all relation files, a feature file, a tag file, and a test index files.**

# %%
# Replace with an S3 location or local path to point to customers' own dataset
data_location = 'fraud-detection-solution'
raw_data_folder = 'raw_data'
processed_data_folder = 'processed_data'
model_output_folder = 'model_output'

processed_data = 's3://{}/{}'.format(data_location, processed_data_folder)
output_path = 's3://{}/{}'.format(data_location, model_output_folder)

print(processed_data)
print(output_path)
# Out:
# s3://fraud-detection-solution/processed_data
# s3://fraud-detection-solution/model_output

# %% [markdown]
# ### View the pre-processed data
#
# Here come the pre-processed file lists

# %% [markdown]
# ## Need to modified this to Neptune dump files!

# %%
from os import path
from sagemaker.s3 import S3Downloader
processed_files = S3Downloader.list(processed_data)
print("===== Processed Files =====")
print('\n'.join(processed_files))
# Out:
# ===== Processed Files =====
# s3://fraud-detection-solution/processed_data/
# s3://fraud-detection-solution/processed_data/features.csv
# s3://fraud-detection-solution/processed_data/relation_DeviceInfo_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_DeviceType_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_P_emaildomain_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_ProductCD_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_R_emaildomain_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_TransactionID_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_addr1_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_addr2_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_card1_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_card2_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_card3_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_card4_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_card5_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_card6_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_01_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_02_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_03_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_04_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_05_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_06_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_07_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_08_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_09_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_10_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_11_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_12_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_13_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_14_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_15_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_16_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_17_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_18_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_19_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_20_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_21_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_22_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_23_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_24_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_25_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_26_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_27_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_28_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_29_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_30_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_31_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_32_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_33_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_34_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_35_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_36_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_37_edgelist.csv
# s3://fraud-detection-solution/processed_data/relation_id_38_edgelist.csv
# s3://fraud-detection-solution/processed_data/tags.csv
# s3://fraud-detection-solution/processed_data/test.csv

# %% [markdown]
# ## Train Graph Neural Network with DGL
#
# Graph Neural Networks work by learning representation for nodes or edges of a graph that are well suited for some downstream task. We can model the fraud detection problem as a node classification task, and the goal of the graph neural network would be to learn how to use information from the topology of the sub-graph for each transaction node to transform the node's features to a representation space where the node can be easily classified as fraud or not.
#
# Specifically, we will be using a relational graph convolutional neural network model (R-GCN) on a heterogeneous graph since we have nodes and edges of different types.

# %% [markdown]
# ### Hyperparameters
#
# To train the graph neural network, we need to define a few hyperparameters that determine properties such as the class of graph neural network models we will be using, the network architecture and the optimizer and optimization parameters.
#
# Here we're setting only a few of the hyperparameters, to see all the hyperparameters and their default values, see `dgl-fraud-detection/estimator_fns.py`. The parameters set below are:
#
# * **`nodes`** is the name of the file that contains the `node_id`s of the target nodes and the node features.
# * **`edges`** is a regular expression that when expanded lists all the filenames for the edgelists
# * **`labels`** is the name of the file tha contains the target `node_id`s and their labels
#
# The following hyperparameters can be tuned and adjusted to improve model performance
# * **embedding-size** is the size of the embedding dimension for non target nodes
# * **n-layers** is the number of GNN layers in the model
# * **n-epochs** is the number of training epochs for the model training job
# * **optimizer** is the optimization algorithm used for gradient based parameter updates
# * **lr** is the learning rate for parameter updates

# %%
edges = ",".join(map(lambda x: x.split("/")[-1], [file for file in processed_files if "relation" in file]))
params = {'nodes' : 'features.csv',
          'edges': 'relation*',
          'labels': 'tags.csv',
          'embedding-size': 64,
          'n-layers': 2,
          'n-epochs': 10,
          'optimizer': 'adam',
          'lr': 1e-2
        }

# print("Graph will be constructed using the following edgelists:\n{}" .format('\n'.join(edges.split(","))))

# %% [markdown]
# ### Create and Fit SageMaker Pytorch Estimator
#
# With the hyperparameters defined, then kick off the training job. Here use the Deep Graph Library (DGL), with Pytorch as the backend deep learning framework, to define and train the graph neural network. Amazon SageMaker makes it do this with the Framework estimators which have the deep learning frameworks already setup. Here, we create a SageMaker Pytorch estimator and pass in our model training script, hyperparameters, as well as the number and type of training instances specified.
#
# Then `fit` the estimator on the the training data location in S3.

# %%
from sagemaker.pytorch import PyTorch
from sagemaker import get_execution_role
from time import strftime, gmtime

estimator = PyTorch(entry_point='fd_sl_train_entry_point.py',
                    source_dir='FD_SL_DGL/gnn_fraud_detection_dgl',
                    role=role, 
                    train_instance_count=1, 
                    train_instance_type='ml.c5.4xlarge',
                    framework_version="1.4.0",
                    py_version='py3',
                    hyperparameters=params,
                    output_path=output_path,
                    sagemaker_session=sess)

training_job_name = "{}-{}".format('GNN_FD_SL_DGL_Train', strftime("%Y-%m-%d-%H-%M-%S", gmtime()))
print(training_job_name)

estimator.fit({'train': processed_data}, job_name=training_job_name)
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# JamesTrain01-2021-01-21-02-30-04
# 2021-01-21 02:30:04 Starting - Starting the training job...
# 2021-01-21 02:30:09 Starting - Launching requested ML instances.........
# 2021-01-21 02:31:36 Starting - Preparing the instances for training...
# 2021-01-21 02:32:34 Downloading - Downloading input data......
# 2021-01-21 02:33:30 Training - Training image download completed. Training in progress..bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-01-21 02:33:31,309 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2021-01-21 02:33:31,312 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2021-01-21 02:33:31,320 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-01-21 02:33:31,323 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-01-21 02:33:31,632 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2021-01-21 02:33:31,632 sagemaker-containers INFO     Generating setup.cfg
# 2021-01-21 02:33:31,632 sagemaker-containers INFO     Generating MANIFEST.in
# 2021-01-21 02:33:31,632 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python -m pip install . -r requirements.txt
# Processing /tmp/tmpgiewqzxf/module_dir
# Collecting dgl==0.4.2
#   Downloading dgl-0.4.2-cp36-cp36m-manylinux1_x86_64.whl (2.4 MB)
# Requirement already satisfied: numpy>=1.14.0 in /opt/conda/lib/python3.6/site-packages (from dgl==0.4.2->-r requirements.txt (line 1)) (1.16.4)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.6/site-packages (from dgl==0.4.2->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: networkx>=2.1 in /opt/conda/lib/python3.6/site-packages (from dgl==0.4.2->-r requirements.txt (line 1)) (2.4)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.6/site-packages (from networkx>=2.1->dgl==0.4.2->-r requirements.txt (line 1)) (4.4.2)
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=26092 sha256=6ae1e2a3b2c11f9c1214eba5c15f0fd667aacad2578eb8ea42d0cff0a53d477e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-o1gii_o8/wheels/c4/4f/39/cc15a19670f2b7b845c13b7cb648bb7cbee3fa1650ced81e6b
# Successfully built default-user-module-name
# Installing collected packages: dgl, default-user-module-name
#   Attempting uninstall: dgl
#     Found existing installation: dgl 0.4.1
#     Uninstalling dgl-0.4.1:
#       Successfully uninstalled dgl-0.4.1
# Successfully installed default-user-module-name-1.0.0 dgl-0.4.2
# WARNING: You are using pip version 20.1.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.
# 2021-01-21 02:33:36,681 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2021-01-21 02:33:36,693 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2021-01-21 02:33:36,704 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2021-01-21 02:33:36,713 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "lr": 0.01,
#         "n-neighbors": 1000,
#         "edges": "relation*",
#         "labels": "tags.csv",
#         "batch-size": 10000,
#         "nodes": "features.csv",
#         "optimizer": "adam",
#         "n-layers": 2,
#         "n-epochs": 10,
#         "embedding-size": 64,
#         "model": "rgcn"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "JamesTrain01-2021-01-21-02-30-04",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://fraud-detection-solution/JamesTrain01-2021-01-21-02-30-04/source/sourcedir.tar.gz",
#     "module_name": "train_dgl_pytorch_entry_point",
#     "network_interface_name": "eth0",
#     "num_cpus": 16,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_dgl_pytorch_entry_point.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":10000,"edges":"relation*","embedding-size":64,"labels":"tags.csv","lr":0.01,"model":"rgcn","n-epochs":10,"n-layers":2,"n-neighbors":1000,"nodes":"features.csv","optimizer":"adam"}
# SM_USER_ENTRY_POINT=train_dgl_pytorch_entry_point.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_dgl_pytorch_entry_point
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=16
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://fraud-detection-solution/JamesTrain01-2021-01-21-02-30-04/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":10000,"edges":"relation*","embedding-size":64,"labels":"tags.csv","lr":0.01,"model":"rgcn","n-epochs":10,"n-layers":2,"n-neighbors":1000,"nodes":"features.csv","optimizer":"adam"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"JamesTrain01-2021-01-21-02-30-04","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://fraud-detection-solution/JamesTrain01-2021-01-21-02-30-04/source/sourcedir.tar.gz","module_name":"train_dgl_pytorch_entry_point","network_interface_name":"eth0","num_cpus":16,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_dgl_pytorch_entry_point.py"}
# SM_USER_ARGS=["--batch-size","10000","--edges","relation*","--embedding-size","64","--labels","tags.csv","--lr","0.01","--model","rgcn","--n-epochs","10","--n-layers","2","--n-neighbors","1000","--nodes","features.csv","--optimizer","adam"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_LR=0.01
# SM_HP_N-NEIGHBORS=1000
# SM_HP_EDGES=relation*
# SM_HP_LABELS=tags.csv
# SM_HP_BATCH-SIZE=10000
# SM_HP_NODES=features.csv
# SM_HP_OPTIMIZER=adam
# SM_HP_N-LAYERS=2
# SM_HP_N-EPOCHS=10
# SM_HP_EMBEDDING-SIZE=64
# SM_HP_MODEL=rgcn
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python train_dgl_pytorch_entry_point.py --batch-size 10000 --edges relation* --embedding-size 64 --labels tags.csv --lr 0.01 --model rgcn --n-epochs 10 --n-layers 2 --n-neighbors 1000 --nodes features.csv --optimizer adam
#
#
# DLG version: 0.4.2
# numpy version:1.16.4 PyTorch version:1.4.0 DGL version:0.4.2
# Namespace(aggregator_type='gcn', alpha=0.2, attn_drop=0.6, batch_size=10000, compute_metrics=True, dropout=0.2, edges='relation*', embedding_size=64, heterogeneous=True, labels='tags.csv', lr=0.01, mini_batch=False, model='rgcn', model_dir='/opt/ml/model', n_epochs=10, n_hidden=16, n_layers=2, n_neighbors=1000, new_accounts='test.csv', no_features=False, nodes='features.csv', num_gpus=0, num_heads=4, num_out_heads=1, optimizer='adam', output_dir='/opt/ml/output/data', predictions='preds.csv', residual=False, target_ntype='TransactionID', threshold=0, training_dir='/opt/ml/input/data/train', weight_decay=0.0005)
# Getting relation graphs from the following edge lists : ['relation_ProductCD_edgelist.csv', 'relation_DeviceType_edgelist.csv', 'relation_card3_edgelist.csv', 'relation_card1_edgelist.csv', 'relation_id_36_edgelist.csv', 'relation_card5_edgelist.csv', 'relation_id_23_edgelist.csv', 'relation_card2_edgelist.csv', 'relation_id_08_edgelist.csv', 'relation_id_05_edgelist.csv', 'relation_card4_edgelist.csv', 'relation_id_35_edgelist.csv', 'relation_P_emaildomain_edgelist.csv', 'relation_id_28_edgelist.csv', 'relation_id_27_edgelist.csv', 'relation_id_16_edgelist.csv', 'relation_id_15_edgelist.csv', 'relation_id_12_edgelist.csv', 'relation_id_01_edgelist.csv', 'relation_id_37_edgelist.csv', 'relation_id_18_edgelist.csv', 'relation_id_11_edgelist.csv', 'relation_R_emaildomain_edgelist.csv', 'relation_id_03_edgelist.csv', 'relation_TransactionID_edgelist.csv', 'relation_card6_edgelist.csv', 'relation_id_09_edgelist.csv', 'relation_id_24_edgelist.csv', 'relation_id_10_edgelist.csv', 'relation_id_21_edgelist.csv', 'relation_id_26_edgelist.csv', 'relation_id_06_edgelist.csv', 'relation_id_31_edgelist.csv', 'relation_id_38_edgelist.csv', 'relation_id_04_edgelist.csv', 'relation_id_02_edgelist.csv', 'relation_id_20_edgelist.csv', 'relation_id_30_edgelist.csv', 'relation_id_32_edgelist.csv', 'relation_DeviceInfo_edgelist.csv', 'relation_addr2_edgelist.csv', 'relation_id_13_edgelist.csv', 'relation_addr1_edgelist.csv', 'relation_id_25_edgelist.csv', 'relation_id_34_edgelist.csv', 'relation_id_22_edgelist.csv', 'relation_id_07_edgelist.csv', 'relation_id_19_edgelist.csv', 'relation_id_33_edgelist.csv', 'relation_id_14_edgelist.csv', 'relation_id_29_edgelist.csv', 'relation_id_17_edgelist.csv']
# Read edges for relation0 from edgelist: /opt/ml/input/data/train/relation_ProductCD_edgelist.csv
# Read edges for relation1 from edgelist: /opt/ml/input/data/train/relation_DeviceType_edgelist.csv
# Read edges for relation2 from edgelist: /opt/ml/input/data/train/relation_card3_edgelist.csv
# Read edges for relation3 from edgelist: /opt/ml/input/data/train/relation_card1_edgelist.csv
# Read edges for relation4 from edgelist: /opt/ml/input/data/train/relation_id_36_edgelist.csv
# Read edges for relation5 from edgelist: /opt/ml/input/data/train/relation_card5_edgelist.csv
# Read edges for relation6 from edgelist: /opt/ml/input/data/train/relation_id_23_edgelist.csv
# Read edges for relation7 from edgelist: /opt/ml/input/data/train/relation_card2_edgelist.csv
# Read edges for relation8 from edgelist: /opt/ml/input/data/train/relation_id_08_edgelist.csv
# Read edges for relation9 from edgelist: /opt/ml/input/data/train/relation_id_05_edgelist.csv
# Read edges for relation10 from edgelist: /opt/ml/input/data/train/relation_card4_edgelist.csv
# Read edges for relation11 from edgelist: /opt/ml/input/data/train/relation_id_35_edgelist.csv
# Read edges for relation12 from edgelist: /opt/ml/input/data/train/relation_P_emaildomain_edgelist.csv
# Read edges for relation13 from edgelist: /opt/ml/input/data/train/relation_id_28_edgelist.csv
# Read edges for relation14 from edgelist: /opt/ml/input/data/train/relation_id_27_edgelist.csv
# Read edges for relation15 from edgelist: /opt/ml/input/data/train/relation_id_16_edgelist.csv
# Read edges for relation16 from edgelist: /opt/ml/input/data/train/relation_id_15_edgelist.csv
# Read edges for relation17 from edgelist: /opt/ml/input/data/train/relation_id_12_edgelist.csv
# Read edges for relation18 from edgelist: /opt/ml/input/data/train/relation_id_01_edgelist.csv
# Read edges for relation19 from edgelist: /opt/ml/input/data/train/relation_id_37_edgelist.csv
# Read edges for relation20 from edgelist: /opt/ml/input/data/train/relation_id_18_edgelist.csv
# Read edges for relation21 from edgelist: /opt/ml/input/data/train/relation_id_11_edgelist.csv
# Read edges for relation22 from edgelist: /opt/ml/input/data/train/relation_R_emaildomain_edgelist.csv
# Read edges for relation23 from edgelist: /opt/ml/input/data/train/relation_id_03_edgelist.csv
# Will add self loop for target later......
# Read edges for relation25 from edgelist: /opt/ml/input/data/train/relation_card6_edgelist.csv
# Read edges for relation26 from edgelist: /opt/ml/input/data/train/relation_id_09_edgelist.csv
# Read edges for relation27 from edgelist: /opt/ml/input/data/train/relation_id_24_edgelist.csv
# Read edges for relation28 from edgelist: /opt/ml/input/data/train/relation_id_10_edgelist.csv
# Read edges for relation29 from edgelist: /opt/ml/input/data/train/relation_id_21_edgelist.csv
# Read edges for relation30 from edgelist: /opt/ml/input/data/train/relation_id_26_edgelist.csv
# Read edges for relation31 from edgelist: /opt/ml/input/data/train/relation_id_06_edgelist.csv
# Read edges for relation32 from edgelist: /opt/ml/input/data/train/relation_id_31_edgelist.csv
# Read edges for relation33 from edgelist: /opt/ml/input/data/train/relation_id_38_edgelist.csv
# Read edges for relation34 from edgelist: /opt/ml/input/data/train/relation_id_04_edgelist.csv
# Read edges for relation35 from edgelist: /opt/ml/input/data/train/relation_id_02_edgelist.csv
# Read edges for relation36 from edgelist: /opt/ml/input/data/train/relation_id_20_edgelist.csv
# Read edges for relation37 from edgelist: /opt/ml/input/data/train/relation_id_30_edgelist.csv
# Read edges for relation38 from edgelist: /opt/ml/input/data/train/relation_id_32_edgelist.csv
# Read edges for relation39 from edgelist: /opt/ml/input/data/train/relation_DeviceInfo_edgelist.csv
# Read edges for relation40 from edgelist: /opt/ml/input/data/train/relation_addr2_edgelist.csv
# Read edges for relation41 from edgelist: /opt/ml/input/data/train/relation_id_13_edgelist.csv
# Read edges for relation42 from edgelist: /opt/ml/input/data/train/relation_addr1_edgelist.csv
# Read edges for relation43 from edgelist: /opt/ml/input/data/train/relation_id_25_edgelist.csv
# Read edges for relation44 from edgelist: /opt/ml/input/data/train/relation_id_34_edgelist.csv
# Read edges for relation45 from edgelist: /opt/ml/input/data/train/relation_id_22_edgelist.csv
# Read edges for relation46 from edgelist: /opt/ml/input/data/train/relation_id_07_edgelist.csv
# Read edges for relation47 from edgelist: /opt/ml/input/data/train/relation_id_19_edgelist.csv
# Read edges for relation48 from edgelist: /opt/ml/input/data/train/relation_id_33_edgelist.csv
# Read edges for relation49 from edgelist: /opt/ml/input/data/train/relation_id_14_edgelist.csv
# Read edges for relation50 from edgelist: /opt/ml/input/data/train/relation_id_29_edgelist.csv
# Read edges for relation51 from edgelist: /opt/ml/input/data/train/relation_id_17_edgelist.csv
# Read in features for target nodes
# Constructed heterograph with the following metagraph structure: Node types ['target', 'ProductCD', 'DeviceType', 'card3', 'card1', 'id_36', 'card5', 'id_23', 'card2', 'id_08', 'id_05', 'card4', 'id_35', 'P_emaildomain', 'id_28', 'id_27', 'id_16', 'id_15', 'id_12', 'id_01', 'id_37', 'id_18', 'id_11', 'R_emaildomain', 'id_03', 'card6', 'id_09', 'id_24', 'id_10', 'id_21', 'id_26', 'id_06', 'id_31', 'id_38', 'id_04', 'id_02', 'id_20', 'id_30', 'id_32', 'DeviceInfo', 'addr2', 'id_13', 'addr1', 'id_25', 'id_34', 'id_22', 'id_07', 'id_19', 'id_33', 'id_14', 'id_29', 'id_17'], Edge types[('target', 'relation0', 'ProductCD'), ('ProductCD', 'rev_relation0', 'target'), ('target', 'relation1', 'DeviceType'), ('DeviceType', 'rev_relation1', 'target'), ('target', 'relation2', 'card3'), ('card3', 'rev_relation2', 'target'), ('target', 'relation3', 'card1'), ('card1', 'rev_relation3', 'target'), ('target', 'relation4', 'id_36'), ('id_36', 'rev_relation4', 'target'), ('target', 'relation5', 'card5'), ('card5', 'rev_relation5', 'target'), ('target', 'relation6', 'id_23'), ('id_23', 'rev_relation6', 'target'), ('target', 'relation7', 'card2'), ('card2', 'rev_relation7', 'target'), ('target', 'relation8', 'id_08'), ('id_08', 'rev_relation8', 'target'), ('target', 'relation9', 'id_05'), ('id_05', 'rev_relation9', 'target'), ('target', 'relation10', 'card4'), ('card4', 'rev_relation10', 'target'), ('target', 'relation11', 'id_35'), ('id_35', 'rev_relation11', 'target'), ('target', 'relation12', 'P_emaildomain'), ('P_emaildomain', 'rev_relation12', 'target'), ('target', 'relation13', 'id_28'), ('id_28', 'rev_relation13', 'target'), ('target', 'relation14', 'id_27'), ('id_27', 'rev_relation14', 'target'), ('target', 'relation15', 'id_16'), ('id_16', 'rev_relation15', 'target'), ('target', 'relation16', 'id_15'), ('id_15', 'rev_relation16', 'target'), ('target', 'relation17', 'id_12'), ('id_12', 'rev_relation17', 'target'), ('target', 'relation18', 'id_01'), ('id_01', 'rev_relation18', 'target'), ('target', 'relation19', 'id_37'), ('id_37', 'rev_relation19', 'target'), ('target', 'relation20', 'id_18'), ('id_18', 'rev_relation20', 'target'), ('target', 'relation21', 'id_11'), ('id_11', 'rev_relation21', 'target'), ('target', 'relation22', 'R_emaildomain'), ('R_emaildomain', 'rev_relation22', 'target'), ('target', 'relation23', 'id_03'), ('id_03', 'rev_relation23', 'target'), ('target', 'relation25', 'card6'), ('card6', 'rev_relation25', 'target'), ('target', 'relation26', 'id_09'), ('id_09', 'rev_relation26', 'target'), ('target', 'relation27', 'id_24'), ('id_24', 'rev_relation27', 'target'), ('target', 'relation28', 'id_10'), ('id_10', 'rev_relation28', 'target'), ('target', 'relation29', 'id_21'), ('id_21', 'rev_relation29', 'target'), ('target', 'relation30', 'id_26'), ('id_26', 'rev_relation30', 'target'), ('target', 'relation31', 'id_06'), ('id_06', 'rev_relation31', 'target'), ('target', 'relation32', 'id_31'), ('id_31', 'rev_relation32', 'target'), ('target', 'relation33', 'id_38'), ('id_38', 'rev_relation33', 'target'), ('target', 'relation34', 'id_04'), ('id_04', 'rev_relation34', 'target'), ('target', 'relation35', 'id_02'), ('id_02', 'rev_relation35', 'target'), ('target', 'relation36', 'id_20'), ('id_20', 'rev_relation36', 'target'), ('target', 'relation37', 'id_30'), ('id_30', 'rev_relation37', 'target'), ('target', 'relation38', 'id_32'), ('id_32', 'rev_relation38', 'target'), ('target', 'relation39', 'DeviceInfo'), ('DeviceInfo', 'rev_relation39', 'target'), ('target', 'relation40', 'addr2'), ('addr2', 'rev_relation40', 'target'), ('target', 'relation41', 'id_13'), ('id_13', 'rev_relation41', 'target'), ('target', 'relation42', 'addr1'), ('addr1', 'rev_relation42', 'target'), ('target', 'relation43', 'id_25'), ('id_25', 'rev_relation43', 'target'), ('target', 'relation44', 'id_34'), ('id_34', 'rev_relation44', 'target'), ('target', 'relation45', 'id_22'), ('id_22', 'rev_relation45', 'target'), ('target', 'relation46', 'id_07'), ('id_07' ...
# Number of nodes of type target : 590540
# Getting labels
# Got labels
# ----Data statistics------'
#                 #Nodes: 726345
#                 #Edges: 19518802
#                 #Features Shape: torch.Size([590540, 390])
#                 #Labeled Train samples: 118108.0
#                 #Unlabeled Test samples: 472432.0
# Initializing Model
# Initialized Model
# Starting Model training
# [2021-01-21 02:37:45.517 algo-1:56 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-01-21 02:37:45.518 algo-1:56 INFO hook.py:191] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-01-21 02:37:45.518 algo-1:56 INFO hook.py:236] Saving to /opt/ml/output/tensors
# [2021-01-21 02:37:45.518 algo-1:56 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2021-01-21 02:37:45.522 algo-1:56 INFO hook.py:376] Monitoring the collections: losses
# [2021-01-21 02:37:45.522 algo-1:56 INFO hook.py:437] Hook is writing from the hook with pid: 56
#
# [2021-01-21 02:37:45.577 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation0 Parameter
# [2021-01-21 02:37:45.609 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation1 Parameter
# [2021-01-21 02:37:45.642 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation2 Parameter
# [2021-01-21 02:37:45.675 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation3 Parameter
# [2021-01-21 02:37:45.708 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation4 Parameter
# [2021-01-21 02:37:45.742 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation5 Parameter
# [2021-01-21 02:37:45.775 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation6 Parameter
# [2021-01-21 02:37:45.802 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation7 Parameter
# [2021-01-21 02:37:45.825 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation8 Parameter
# [2021-01-21 02:37:45.847 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation9 Parameter
# [2021-01-21 02:37:45.869 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation10 Parameter
# [2021-01-21 02:37:45.892 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation11 Parameter
# [2021-01-21 02:37:45.914 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation12 Parameter
# [2021-01-21 02:37:45.936 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation13 Parameter
# [2021-01-21 02:37:45.959 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation14 Parameter
# [2021-01-21 02:37:45.983 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation15 Parameter
# [2021-01-21 02:37:46.006 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation16 Parameter
# [2021-01-21 02:37:46.029 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation17 Parameter
# [2021-01-21 02:37:46.053 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation18 Parameter
# [2021-01-21 02:37:46.076 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation19 Parameter
# [2021-01-21 02:37:46.099 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation20 Parameter
# [2021-01-21 02:37:46.122 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation21 Parameter
# [2021-01-21 02:37:46.145 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation22 Parameter
# [2021-01-21 02:37:46.168 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation23 Parameter
# [2021-01-21 02:37:46.191 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation25 Parameter
# [2021-01-21 02:37:46.213 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation26 Parameter
# [2021-01-21 02:37:46.235 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation27 Parameter
# [2021-01-21 02:37:46.258 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation28 Parameter
# [2021-01-21 02:37:46.280 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation29 Parameter
# [2021-01-21 02:37:46.302 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation30 Parameter
# [2021-01-21 02:37:46.325 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation31 Parameter
# [2021-01-21 02:37:46.347 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation32 Parameter
# [2021-01-21 02:37:46.369 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation33 Parameter
# [2021-01-21 02:37:46.391 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation34 Parameter
# [2021-01-21 02:37:46.419 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation35 Parameter
# [2021-01-21 02:37:46.441 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation36 Parameter
# [2021-01-21 02:37:46.464 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation37 Parameter
# [2021-01-21 02:37:46.487 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation38 Parameter
# [2021-01-21 02:37:46.511 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation39 Parameter
# [2021-01-21 02:37:46.535 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation40 Parameter
# [2021-01-21 02:37:46.558 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation41 Parameter
# [2021-01-21 02:37:46.581 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation42 Parameter
# [2021-01-21 02:37:46.604 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation43 Parameter
# [2021-01-21 02:37:46.629 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation44 Parameter
# [2021-01-21 02:37:46.653 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation45 Parameter
# [2021-01-21 02:37:46.678 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation46 Parameter
# [2021-01-21 02:37:46.703 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation47 Parameter
# [2021-01-21 02:37:46.728 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation48 Parameter
# [2021-01-21 02:37:46.753 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation49 Parameter
# [2021-01-21 02:37:46.778 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation50 Parameter
# [2021-01-21 02:37:46.803 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0.weight.rev_relation51 Parameter
# [2021-01-21 02:37:57.749 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0 DGLHeteroGraph
# [2021-01-21 02:37:57.749 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0 dict
# [2021-01-21 02:37:57.749 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.0 dict
# [2021-01-21 02:38:07.405 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.1 DGLHeteroGraph
# [2021-01-21 02:38:07.405 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.1 dict
# [2021-01-21 02:38:07.405 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:layers.1 dict
# [2021-01-21 02:38:07.407 algo-1:56 WARNING hook.py:898] var is not Tensor or list or tuple of Tensors, module_name:HeteroRGCN DGLHeteroGraph
# Epoch 00000 | Time(s) 38.9127 | Loss 0.4637 | f1 0.0000
# Epoch 00001 | Time(s) 38.0535 | Loss 0.9163 | f1 0.0097
# Epoch 00002 | Time(s) 37.5218 | Loss 0.5926 | f1 0.0330
# Epoch 00003 | Time(s) 37.2649 | Loss 0.3099 | f1 0.1682
# Epoch 00004 | Time(s) 37.1678 | Loss 0.8407 | f1 0.1806
# Epoch 00005 | Time(s) 37.0568 | Loss 0.2275 | f1 0.0203
# Epoch 00006 | Time(s) 37.0048 | Loss 0.2538 | f1 0.0023
# Epoch 00007 | Time(s) 36.9389 | Loss 0.3028 | f1 0.0000
# Epoch 00008 | Time(s) 36.9076 | Loss 0.3156 | f1 0.0000
# Epoch 00009 | Time(s) 36.8019 | Loss 0.2967 | f1 0.0011
# Metrics
# Confusion Matrix:
#                                                     labels positive  labels negative
# predicted positive               11                1
# predicted negative            17826           454594
#                                 f1: 0.0012, precision: 0.9167, recall: 0.0006, acc: 0.9623, roc: 0.4070, pr: 0.0407, ap: 0.0408
#
# Finished Model training
# Saving model
# [2021-01-21 02:48:02.838 algo-1:56 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# 2021-01-21 02:48:03,525 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2021-01-21 02:48:39 Uploading - Uploading generated training model
# 2021-01-21 02:54:29 Completed - Training job completed
# Training seconds: 1315
# Billable seconds: 1315

# %% [markdown]
# Once the training is completed, the training instances are automatically saved and SageMaker stores the trained model and evaluation results to a location in S3.
